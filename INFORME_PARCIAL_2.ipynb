# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresVelez31/Parcial-2-Estructuras-de-Datos-y-Algoritmos-I/blob/main/INFORME_PARCIAL_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align="center">Informe Parcial 2</h1>

# %% [markdown]
# *Realizado por: Andres Felipe Velez Alvarez y Nicolas Serna Perez*

# %% [markdown]
# ## **1. AVL vs Arboles Binario**

# %% [markdown]
# ### **Descripción del funcionamiento de los Árboles AVL y su diferencia con los Árboles Binarios de Búsqueda.**

# %% [markdown]
# Un árbol binario de búsqueda (BST) es una estructura donde cada nodo tiene dos hijos (izquierdo y derecho), y está organizado de tal manera que:
#
# Todos los nodos en el subárbol izquierdo son menores que el nodo principal.
# Todos los nodos en el subárbol derecho son mayores.
# El problema es que, aunque normalmente permite búsquedas rápidas, si el árbol se desbalancea (uno de los lados crece mucho más que el otro), las búsquedas se vuelven lentas. En los peores casos, el rendimiento de las búsquedas y otras operaciones puede llegar a ser igual que en una lista enlazada.
#
# Por otro lado, los árboles AVL son árboles binarios de búsqueda que se mantienen balanceados. Esto significa que la diferencia de altura entre los subárboles de cualquier nodo es siempre como máximo 1. Para lograr esto, los árboles AVL realizan rotaciones automáticas después de insertar o eliminar nodos, manteniendo el árbol siempre equilibrado.
#
# ![alt text](https://media.geeksforgeeks.org/wp-content/cdn-uploads/20221215114732/bst-21.png)
#
# ![alt text](https://media.geeksforgeeks.org/wp-content/uploads/20221229121830/avl.png)

# %% [markdown]
# ### **Diferencias principales:**

# %% [markdown]
# #### **Balanceo:**
#
# - **BST:** No garantizan un balanceo, por lo que pueden desbalancearse si las inserciones siguen un patrón desfavorable, como insertar nodos en orden ascendente o descendente. Esto puede provocar que el árbol se asemeje a una lista enlazada, lo que afecta negativamente el rendimiento.
#
# - **AVL:** Se autoajustan para mantenerse balanceados. Después de cada inserción o eliminación, el árbol comprueba el equilibrio y, si es necesario, realiza rotaciones para asegurar que la diferencia de altura entre los subárboles izquierdo y derecho de cualquier nodo nunca sea mayor que 1.
#
# #### **Rendimiento:**
#
# - **BST:** En su forma ideal, ofrecen búsquedas, inserciones y eliminaciones en tiempo O(log n), pero en el peor de los casos, si se desbalancean, las operaciones pueden degradarse a O(n), lo que significa que pierden eficiencia.
#
# - **AVL:** Gracias a su balanceo constante, las operaciones se realizan siempre en O(log n), lo que garantiza un rendimiento óptimo incluso en el peor de los casos, independientemente del orden de inserción o eliminación.
#
# #### **Rotaciones:**
#
# - **BST:** No realizan rotaciones, lo que permite que el árbol se desbalancee sin intervención.
#
# - **AVL:** Utilizan rotaciones simples (izquierda o derecha) y dobles (izquierda-derecha o derecha-izquierda) para restaurar el equilibrio del árbol. Estas rotaciones son rápidas y se aplican localmente en las áreas desbalanceadas.
#
# ##### **Altura del árbol:**
#
# - **BST:** La altura puede crecer de manera desproporcionada en árboles desbalanceados, aumentando la profundidad y por lo tanto el tiempo necesario para realizar búsquedas o inserciones.
#
# - **AVL:** La altura se mantiene cerca de log(n) debido al balanceo, lo que asegura que las operaciones de búsqueda, inserción y eliminación se mantengan eficientes.
#
# #### **Costo de mantenimiento:**
#
# - **BST:** No tienen un costo adicional por mantener el equilibrio, ya que no realizan rotaciones. Esto los hace más simples en su implementación, pero menos eficientes cuando se desbalancean.
# - **AVL:** Tienen un pequeño costo adicional debido a las rotaciones después de cada inserción o eliminación, pero este costo es mínimo y asegura que el rendimiento general del árbol sea óptimo a largo plazo.

# %% [markdown]
# ## **2. Rotaciones**

# %% [markdown]
# ### **Implementacion de rotaciones para mantener el balance en un AVL**
#
# En un árbol AVL, las **rotaciones** se implementan para restaurar el balance después de una inserción o eliminación que cause un desbalance en el árbol. El balance de un nodo se determina por la diferencia de alturas entre su subárbol izquierdo y derecho (balance factor), y debe estar entre -1 y 1. Si el balance excede estos límites, se ejecuta una rotación.
#
# Las rotaciones básicas son:
#
# #### **Rotacion Simple Derecha (LL):**
# *  Ocurre cuando un nodo tiene un subárbol izquierdo más pesado.
# *  El subárbol derecho del hijo izquierdo pasa a ser el subárbol izquierdo del nodo desbalanceado, y el hijo izquierdo toma su lugar.
#
# ![alt text](https://player.slideplayer.es/8/2438423/data/images/img4.jpg)
#
# #### **Rotacion Simple Izquierda (RR):**
# *  Se utiliza cuando un nodo tiene un subárbol derecho más pesado.
# *  Se mueve el subárbol izquierdo del hijo derecho como subárbol derecho del
# nodo desbalanceado, y el hijo derecho toma la posición del nodo desbalanceado.
#
# ![alt text](https://player.slideplayer.es/8/2438423/data/images/img2.png)
#
# #### **Rotacion Izquierda Derecha (LR):**
# * Cuando un subárbol izquierdo del nodo está desbalanceado hacia la derecha.
# * Se realiza una rotación simple a la izquierda sobre el hijo izquierdo, seguida de
# una rotación simple a la derecha sobre el nodo desbalanceado.
#
# ![alt text](https://player.slideplayer.es/8/2438423/data/images/img6.png)
#
# #### **Rotacion Derecha Izquierda (RL):**
# * Aparece cuando el subárbol derecho está desbalanceado hacia la izquierda.
# * Se realiza una rotación a la derecha sobre el hijo derecho, luego una rotación a
# la izquierda sobre el nodo desbalanceado
#
# ![alt text](https://player.slideplayer.es/8/2438423/data/images/img8.png)

# %% [markdown]
# ## **3. Insercion y Eliminacion**

# %% [markdown]
# ### **Análisis de la complejidad de las operaciones de inserción y eliminación en un Árbol AVL.**
#
# ####**Complejidad de Inserción**
# 1. **Búsqueda del lugar de inserción:**
#
# - En un árbol AVL, al igual que en un árbol binario de búsqueda (BST), se realiza una búsqueda para encontrar la posición adecuada para insertar un nuevo nodo. La complejidad de esta búsqueda es
# $𝑂 (ℎ)$, donde $ℎ$ es la altura del árbol.
#
# 2. **Actualización de la altura y balanceo:**
#
# - Después de insertar un nodo, es necesario actualizar las alturas de los nodos ancestros y verificar el balance del árbol desde el nodo insertado hasta la raíz. Esta operación también tiene una complejidad de $𝑂(ℎ)$.
#
# - En el peor de los casos, se pueden requerir rotaciones para mantener el balance. Hay un número constante (a lo sumo 2) de rotaciones necesarias para restaurar el equilibrio del árbol en el caso de un desequilibrio.
# Complejidad total:
#
# 3. **Complejidad total:**
#
# - Dado que la altura de un árbol AVL es  $𝑂 (log (n))$ (donde 𝑛 es el número de nodos), la complejidad total de la operación de inserción es: $𝑂 (log (𝑛))$.
#
#
# ![alt text](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhbulY1k7nzgGYlcgaq1CuZrKT1r6MfIcdfZhBR_XgVRAkBnyZFwuClxhz0hcJJcP-SWWrLdMO8I9Ox0Sz-0LidNrTe4xlG_-nPedqd_Dv_6MJtNgL2SBh_AS1QvZnn7WJ0PfsOj0zVNZU/s1600/rotacionSimple3.gif)
#
#
# #### **Complejidad de Eliminación**
# 1. **Búsqueda del nodo a eliminar:**
#
# - Similar a la inserción, primero se debe buscar el nodo a eliminar. Esta operación también tiene una complejidad de
# $𝑂(ℎ)$.
#
# 2. **Eliminación del nodo:**
#
# - Al eliminar un nodo, se puede eliminar directamente si es una hoja, o se debe encontrar un sustituto si tiene uno o dos hijos. Esta operación se realiza en
# $𝑂(ℎ)$.
#
# 3. **Actualización de la altura y balanceo:**
#
# - Al igual que en la inserción, se debe actualizar la altura y verificar el balance desde el nodo padre del nodo eliminado hasta la raíz. Esto también tiene una complejidad de $𝑂(ℎ)$.
#
# - En caso de que se produzca un desequilibrio, se llevarán a cabo las rotaciones necesarias para equilibrar el árbol, lo que también tiene un costo constante.
#
# 4. **Complejidad total:**
#
# Por lo tanto, al igual que con la inserción, la complejidad total de la operación de eliminación es: $𝑂(log (n))$.
#
# ![alt text](https://www.ibiblio.org/pub/Linux/docs/LuCaS/Tutoriales/doc-programacion-arboles-avl/htmls/tree13.png)

# %% [markdown]
# ## **Documentacion - Codigo y Descripcion**

# %% [markdown]
# ### Clase `Nodo`

# %% [markdown]
# ```python
# class Nodo:
#     def __init__(self, valor, padre=None):
#         self.valor = valor
#         self.padre = padre
#         self.izquierda = None
#         self.derecha = None
#         self.altura = 1
# ```
#
# ***`class Nodo`:*** Representa un nodo en un árbol AVL. Cada nodo tiene varios atributos relacionados con su estructura dentro del árbol y su balanceo. La clase es una plantilla para crear estos nodos.
#
# **Método *`__init__`*:** Es el método que se ejecuta cuando se crea una nueva instancia de la clase Nodo. Permite inicializar las propiedades del nodo como su valor, su padre y otros enlaces.
#
# - ***`valor`:*** Este es el valor que almacena el nodo, como el dato principal que identifica al nodo en el árbol. El valor se pasa como argumento cuando se crea el nodo.
#
# - ***`padre`:*** Este es un enlace al nodo padre en el árbol. Si el nodo es la raíz del árbol, su padre será None. Este valor también se pasa como argumento cuando se crea el nodo, pero tiene un valor predeterminado de None, lo que indica que el nodo puede no tener padre al inicio.
#
# - ***`izquierda`:*** Este atributo representa el enlace al hijo izquierdo del nodo. Si no tiene un hijo a la izquierda, este enlace será None. Se inicializa como None cuando se crea el nodo, pero puede cambiar más adelante si se inserta un nodo en la posición izquierda.
#
# - ***`derecha`:*** Similar a izquierda, este atributo es el enlace al hijo derecho del nodo. Se inicializa como None cuando el nodo se crea y cambiará si se inserta un nodo a la derecha.
#
# - ***`altura`:*** Este atributo indica la altura del nodo dentro del árbol. La altura se define como la longitud del camino más largo desde el nodo hasta una hoja (nodo sin hijos). En un árbol AVL, la altura se usa para verificar si el árbol está balanceado. Se inicializa en 1 bajo la suposición de que un nodo recién creado no tiene hijos, por lo tanto, es una hoja.

# %% [markdown]
# ### Clase `ArbolAVL`

# %% [markdown]
# ```python
# class ArbolAVL:
#
# ```
#
# La clase ArbolAVL representa un árbol AVL, que es un tipo de árbol binario de búsqueda balanceado. Mantiene su equilibrio mediante rotaciones después de cada inserción o eliminación de nodos.

# %% [markdown]
# #### Metodo `__init__`

# %% [markdown]
# ```python
# def __init__(self):
#         self.raiz = None
# ```
#
# Este es el constructor de la clase, y se ejecuta cada vez que se crea una nueva instancia del árbol AVL. La palabra clave ***`self`*** se refiere a la instancia del árbol que se está creando, lo que permite que los atributos sean específicos para cada árbol.
#
# - ***`self.raiz = None`:*** Aquí se está definiendo un atributo llamado raiz para la instancia del árbol AVL. Inicialmente, el valor de raiz se establece como None, lo que significa que el árbol está vacío y no tiene ningún nodo aún. Una vez que se inserte un primer nodo, este atributo apuntará al nodo raíz del árbol.

# %% [markdown]
# #### Metodo `insertar`

# %% [markdown]
# ``` python
# def insertar(self, valor, nodo_actual):
#         if not self.raiz:
#             self.raiz = Nodo(valor)
#             return
#
#         if valor < nodo_actual.valor:
#             if nodo_actual.izquierda:
#                 self.insertar(valor, nodo_actual.izquierda)
#             else:
#                 nodo_actual.izquierda = Nodo(valor, nodo_actual)
#                 self._revisar_insertar(nodo_actual.izquierda)
#         elif valor > nodo_actual.valor:
#             if nodo_actual.derecha:
#                 self.insertar(valor, nodo_actual.derecha)
#             else:
#                 nodo_actual.derecha = Nodo(valor, nodo_actual)
#                 self._revisar_insertar(nodo_actual.derecha)
#         else:
#             print("El Valor que estas insertando ya se encuentra en el arbol")
# ```
#
# El método `insertar` en la clase `ArbolAVL` permite agregar nuevos nodos al árbol AVL, manteniendo la propiedad de equilibrio del árbol.
#
# **Parametros del metodo:**
# ```python
# def insertar(self, valor, nodo_actual):
# ```
#
# - ***`self`:*** Hace referencia a la instancia actual de la clase ArbolAVL. Permite que el método acceda a las propiedades y otros métodos de la instancia, como por ejemplo la raíz del árbol y las funciones auxiliares.
#
# - ***`valor`:*** Es el valor que queremos insertar en el árbol AVL. Este valor será almacenado en el nuevo nodo.
#
# - ***`nodo_actual`:*** Es el nodo desde el cual el método comienza a buscar la posición adecuada para insertar el nuevo valor. Generalmente, la primera vez que se llama a este método, se pasa la raíz del árbol como nodo_actual
#
# **Funcionamiento del metodo**
#
# ```python
# if not self.raiz:
#     self.raiz = Nodo(valor)
#     return
# ```
# 1. El método verifica si el árbol está vacío, es decir, si la raíz es None. Si el árbol no tiene nodos (cuando se llama a insertar por primera vez en un árbol vacío), se crea un nuevo nodo con el valor dado y se establece como la raíz del árbol.
#
# ```python
# if valor < nodo_actual.valor:
# ```
# 2. Si el árbol ya tiene nodos, se compara el valor que queremos insertar con el valor del nodo actual (nodo_actual.valor). Si el valor es menor, significa que el nuevo nodo debe colocarse en el subárbol izquierdo.
#
# ```python
# if nodo_actual.izquierda:
#     self.insertar(valor, nodo_actual.izquierda)
# else:
#     nodo_actual.izquierda = Nodo(valor, nodo_actual)
#     self._revisar_insertar(nodo_actual.izquierda)
# ```
# *   Si el subárbol izquierdo ya existe, el método se llama recursivamente para seguir buscando una posición adecuada en ese subárbol.
# *   Si no existe un nodo en el subárbol izquierdo, se crea un nuevo nodo con el valor dado y se asigna como el hijo izquierdo del nodo actual.
# *   Después de insertar el nuevo nodo, se llama a _revisar_insertar para verificar si se necesita realizar alguna operación de equilibrio en el árbol.
#
# ```python
# elif valor > nodo_actual.valor:
#     if nodo_actual.derecha:
#         self.insertar(valor, nodo_actual.derecha)
#     else:
#         nodo_actual.derecha = Nodo(valor, nodo_actual)
#         self._revisar_insertar(nodo_actual.derecha)
# ```
#
# * Si el valor a insertar es mayor que el valor del nodo actual, el método sigue el mismo proceso pero en el subárbol derecho.
# *  Si el nodo derecho ya existe, el método insertar se llama recursivamente para seguir buscando una posición en el subárbol derecho.
# * Si no existe un hijo derecho, se inserta el nuevo nodo en esa posición y luego se llama a _revisar_insertar para verificar si es necesario reequilibrar el árbol.
#
# ```python
# else:
#     print("El Valor que estas insertando ya se encuentra en el arbol")
# ```
# Si el valor que se quiere insertar ya existe en el árbol (es igual al valor de nodo_actual), se imprime un mensaje informando que el valor ya está en el árbol. El árbol AVL no permite valores duplicados, por lo que no se hace ninguna inserción en este caso.

# %% [markdown]
# #### Metodo `_revisar_insertar`

# %% [markdown]
# ``` python
# def _revisar_insertar(self, nodo_actual, camino=[]):
#         if nodo_actual.padre is None: return
#         camino = [nodo_actual] + camino
#
#         balance = self._obtener_balance(nodo_actual.padre)
#
#         if abs(balance) > 1:
#             camino = [nodo_actual.padre] + camino
#             self._reequilibrar_nodo(camino[0], camino[1], camino[2])
#             return
#
#         nueva_altura = 1 + nodo_actual.altura
#
#         if nueva_altura > nodo_actual.padre.altura:
#             nodo_actual.padre.altura = nueva_altura
#
#         self._revisar_insertar(nodo_actual.padre, camino)
# ```
#
# El método `_revisar_insertar` es clave para mantener el balance de un árbol AVL después de insertar un nuevo nodo. Se encarga de verificar si el árbol está balanceado y, si no lo está, inicia el proceso de reequilibrio.
#
# **Parametros del metodo:**
# ```python
# def _revisar_insertar(self, nodo_actual, camino=[]):
# ```
#
# - ***`self`:*** Hace referencia a la instancia actual de la clase ArbolAVL. Permite que el método acceda a las propiedades y otros métodos de la instancia, como por ejemplo la raíz del árbol y las funciones auxiliares.
#
# - ***`nodo_actual`:*** Es el nodo que acabamos de insertar o donde podría haberse producido un desequilibrio.
#
# - ***`camino`:*** Es una lista que contiene los nodos por los que hemos pasado, desde el nodo actual hasta la raíz. Comienza como una lista vacía.
#
# **Funcionamiento del metodo**
#
# **1. Verificar si hemos alcanzado la raíz:**
# ```python
# if nodo_actual.padre is None: return
# ```
#
# Si el *`nodo_actual`* no tiene padre (es la raíz), el proceso de revisión termina porque no es necesario verificar el balance más arriba en el árbol. Si estamos en un nodo hijo, continuamos revisando.
#
#
# **2. Actualizar el camino:**
# ```python
# camino = [nodo_actual] + camino
# ```
#
# Se actualiza el camino agregando el *`nodo_actual`* al inicio de la lista. Esto mantiene el orden de los nodos desde el actual hasta la raíz, lo que es importante si necesitamos rebalancear.
#
#
# **3. Calcular el balance del nodo padre:**
# ```python
# balance = self._obtener_balance(nodo_actual.padre)
# ```
#
# Se obtiene el balance del nodo padre. El balance indica la diferencia de altura entre los subárboles izquierdo y derecho del nodo. Un valor de $0$, $1$ o $-1$ indica que el árbol está balanceado en ese nodo. Si el valor es mayor que $1$ o menor que $-1$, el nodo está desequilibrado.
#
#
# **4. Verificar si el balance es mayor a 1:**
# ```python
# if abs(balance) > 1:
#     camino = [nodo_actual.padre] + camino
#     self._reequilibrar_nodo(camino[0], camino[1], camino[2])
#     return
# ```
#
# - Si el balance es mayor que $1$ o menor que $-1$ (en valor absoluto), significa que el nodo está desequilibrado y necesita ser reequilibrado.
#
# - Se actualiza el *`camino`* para incluir el padre y luego se llama al método `_reequilibrar_nodo`, que utiliza los nodos de este camino para corregir el desequilibrio mediante rotaciones. Después de reequilibrar, la función termina.
#
#
# **5. Actualizar la altura del nodo padre si es necesario:**
# ```python
# nueva_altura = 1 + nodo_actual.altura
# if nueva_altura > nodo_actual.padre.altura:
#     nodo_actual.padre.altura = nueva_altura
# ```
#
# Se calcula una nueva altura potencial para el nodo padre. Si la nueva altura es mayor que la altura actual del nodo padre, significa que el subárbol creció, por lo que se actualiza la altura del nodo padre.
#
#
# **6. Llamada recursiva para revisar el padre:**
# ```python
# self._revisar_insertar(nodo_actual.padre, camino)
# ```
#
# Después de actualizar la altura del padre, la función se llama de nuevo recursivamente con el nodo padre como nuevo *`nodo_actual`*, y el *`camino`* actualizado. Este proceso continúa hasta que se llegue a la raíz o se detecte un desequilibrio.

# %% [markdown]
# #### Metodo `_obtener_balance`

# %% [markdown]
# ```python
# def _obtener_balance(self, nodo_actual):
#         if nodo_actual is None:
#             return 0
#         return self._obtener_altura(nodo_actual.izquierda) - self._obtener_altura(nodo_actual.derecha)
# ```
#
# El método _obtener_balance es una función que se utiliza para calcular el balance de un nodo en un árbol AVL. Este balance es la diferencia de altura entre el subárbol izquierdo y el subárbol derecho del nodo, lo que ayuda a determinar si el nodo está equilibrado.
#
# **Parametros del metodo:**
# ```python
# def _obtener_balance(self, nodo_actual):
# ```
# Al igual que el metodo *`obtener_minimo`* y *`obtener_maximo`*, este metodo recibe 2 parametros:
#
# - *`self:`* Hace referencia a la instancia actual del árbol AVL. Esto permite acceder a otros métodos y atributos dentro de la clase.
# - *`nodo_actual:`* Es el nodo cuyo balance (diferencia de altura entre sus subárboles) se quiere calcular. Este nodo puede ser cualquier nodo dentro del árbol AVL, o puede ser *`None`*.
#
#
# **Funcionamiento del metodo**
#
# **1. Verificación de nodo nulo::**
# ```python
# if nodo_actual is None:
#     return 0
# ```
#
# - Primero, el método comprueba si el *`nodo_actual`* es *`None`*, lo cual significa que no existe ese nodo. En este caso, el balance se considera $0$ porque no hay subárboles que comparar.
#
# - Este es un caso base que se usa para evitar errores al tratar con nodos vacíos.
#
#
# **2. Cálculo del balance::**
# ```python
# return self._obtener_altura(nodo_actual.izquierda) - self._obtener_altura(nodo_actual.derecha)
# ```
#
# - La función calcula el balance del nodo como la diferencia entre la altura del subárbol izquierdo y la altura del subárbol derecho.
#
# - Para obtener estas alturas, se llama al método auxiliar `_obtener_altura` en ambos subárboles: el izquierdo (*`nodo_actual.izquierda`*) y el derecho (*`nodo_actual.derecha`*).
#
# - Posibles valores del balance:
#
#   - Si el balance es $0$, significa que los subárboles izquierdo y derecho tienen la misma altura, por lo que el nodo está perfectamente equilibrado.
#
#   - Si el balance es positivo (por ejemplo, $1$), significa que el subárbol izquierdo es más alto que el derecho.
#
#   - Si el balance es negativo (por ejemplo, $-1$), significa que el subárbol derecho es más alto que el izquierdo.

# %% [markdown]
# #### Metodo `_obtener_altura`

# %% [markdown]
# ```python
# def _obtener_altura(self, nodo_actual):
#         if nodo_actual is None: return 0
#         return nodo_actual.altura
# ```
#
# El método _obtener_altura permite obtener la altura de un nodo en el árbol AVL.
# Es importante porque la altura de los nodos es esencial para calcular el balanceo del árbol y decidir si se necesitan realizar rotaciones para mantener el equilibrio del árbol AVL.
#
#
# **Parametros del metodo:**
# ```python
# def _obtener_altura(self, nodo_actual):
# ```
# Al igual que el metodo *`obtener_minimo`*, *`obtener_maximo`* y *`obtener_balance`* , este metodo recibe 2 parametros:
#
# - *`self:`* Es el objeto de la clase *`ArbolAVL`*, lo que permite acceder a otros métodos y atributos de la clase.
# - *`nodo_actual:`* Es el nodo del cual se quiere conocer la altura. Este parámetro puede ser un nodo específico o *`None`*.
#
#
# **Funcionamiento del metodo**
#
# **1. Verificar si el nodo es nulo:**
# ```python
# if nodo_actual is None: return 0
# ```
#
# - El método primero comprueba si el *`nodo_actual`* es *`None`*. Esto ocurre cuando el nodo no existe o si se ha alcanzado una hoja sin hijos.
#
# - Si es *`None`*, la altura devuelta será $0$. Esto tiene sentido porque un nodo inexistente no tiene ninguna altura.
#
#
# **2. Devolver la altura del nodo:**
# ```python
# return self._obtener_altura(nodo_actual.izquierda) - self._obtener_altura(nodo_actual.derecha)
# ```
#
# - Si el *`nodo_actual`* no es *`None`*, el método devuelve el valor almacenado en el atributo altura del nodo.
#
# - La altura de un nodo representa la cantidad de niveles que hay entre ese nodo y el nodo hoja más profundo en su subárbol. Este valor es clave para mantener el balance en un árbol AVL.

# %% [markdown]
# #### Metodo `_reequilibrar_nodo`

# %% [markdown]
# ```python
# def _reequilibrar_nodo(self, z, y, x):
#         if y == z.izquierda and x == y.izquierda:
#             self._rotar_derecha(z)
#         elif y == z.izquierda and x == y.derecha:
#             self._rotar_izquierda(y)
#             self._rotar_derecha(z)
#         elif y == z.derecha and x == y.derecha:
#             self._rotar_izquierda(z)
#         elif y == z.derecha and x == y.izquierda:
#             self._rotar_derecha(y)
#             self._rotar_izquierda(z)
#         else:
#             raise Exception('_reequilibrar_nodo: ¡Configuración de nodos z, y, x no reconocida!')
# ```
#
# El método `_reequilibrar_nodo` se encarga de restablecer el equilibrio en el árbol AVL mediante rotaciones. Esto ocurre cuando se detecta un desequilibrio en el árbol después de una operación de inserción o eliminación.
#
#
# **Parametros del metodo:**
# ```python
# def _reequilibrar_nodo(self, z, y, x):
# ```
#
# - *`self:`* Es el objeto de la clase *`ArbolAVL`*, lo que permite acceder a otros métodos y atributos de la clase.
# - *`z`*: Es el nodo que está desequilibrado. Es el "abuelo" en la relación de tres nodos (z, y, x).
# - *`y`*: Es el hijo de *`z`*, uno de los nodos involucrados en el desequilibrio.
# - *`x`*: Es el hijo de *`y`*, el nodo más profundo que provocó el desequilibrio.
#
#
# **Funcionamiento del metodo**
#
# **1. Primera Condición: Rotación simple a la derecha:**
# ```python
# if y == z.izquierda and x == y.izquierda:
#     self._rotar_derecha(z)
# ```
#
# - Este caso ocurre cuando y es el hijo izquierdo de *`z`* y *`x`* es el hijo izquierdo de *`y`*. Este es un caso de desequilibrio conocido como "desbalanceo hacia la izquierda-izquierda" (left-left).
#
# - Para corregir este desbalance, se aplica una rotación simple a la derecha sobre el nodo *`z`*.
#
#
# **2. Segunda Condición: Rotación doble (izquierda-derecha):**
# ```python
# elif y == z.izquierda and x == y.derecha:
#     self._rotar_izquierda(y)
#     self._rotar_derecha(z)
# ```
#
# - Aquí y sigue siendo el hijo izquierdo de *`z`*, pero *`x`* es el hijo derecho de y. Esto genera un desequilibrio conocido como "desbalanceo izquierda-derecha" (left-right).
#
# - Para corregirlo, primero se aplica una rotación a la izquierda sobre *`y`* y luego una rotación a la derecha sobre *`z`*.
#
#
# **3. Tercera Condición: Rotación simple a la izquierda:**
# ```python
# elif y == z.derecha and x == y.derecha:
#     self._rotar_izquierda(z)
# ```
#
# - En este caso, tanto y como x son hijos derechos (de *`z`* y *`y`*, respectivamente). Este es un caso de "desbalanceo hacia la derecha-derecha" (right-right).
#
# - Para corregirlo, se realiza una rotación simple a la izquierda sobre *`z`*.
#
#
# **4. Cuarta Condición: Rotación doble (derecha-izquierda):**
# ```python
# elif y == z.derecha and x == y.izquierda:
#     self._rotar_derecha(y)
#     self._rotar_izquierda(z)
# ```
#
# - Aquí y es el hijo derecho de *`z`*, pero *`x`* es el hijo izquierdo de *`y`*. Esto causa un "desbalanceo derecha-izquierda" (right-left).
#
# - Para corregirlo, se hace primero una rotación a la derecha sobre *`y`* y luego una rotación a la izquierda sobre *`z`*.
#
#
# **5. Manejo de casos inesperados:**
# ```python
# else:
#     raise Exception('_reequilibrar_nodo: ¡Configuración de nodos z, y, x no reconocida!')
# ```
#
# Si ninguna de las combinaciones anteriores se cumple, se genera una excepción, indicando que la configuración de los nodos no es válida o reconocida.

# %% [markdown]
# #### Metodo `_rotar_derecha`

# %% [markdown]
# ```python
# def _rotar_derecha(self, y):
#         sub_raiz = y.padre
#         z = y.izquierda
#         t3 = z.derecha
#         z.derecha = y
#         y.padre = z
#         y.izquierda = t3
#
#         if t3 is not None:
#             t3.padre = y
#
#         z.padre = sub_raiz
#
#         if z.padre is None:
#             self.raiz = z
#         else:
#             if z.padre.izquierda == y:
#                 z.padre.izquierda = z
#             else:
#                 z.padre.derecha = z
#
#         y.altura = 1 + max(self._obtener_altura(y.izquierda), self._obtener_altura(y.derecha))
#         z.altura = 1 + max(self._obtener_altura(z.izquierda), self._obtener_altura(z.derecha))
# ```
#
# El método `_rotar_derecha` se utiliza para realizar una **rotación simple a la derecha (LL)** en un árbol AVL. Este tipo de rotación se aplica cuando un nodo está desbalanceado hacia la izquierda, es decir, cuando la subárbol izquierdo de un nodo es más alto que el derecho. La rotación derecha redistribuye los nodos de tal manera que el árbol vuelva a estar equilibrado.
#
# El nodo izquierdo (*`z`*) de *`y`* se mueve hacia arriba, convirtiéndose en la nueva raíz de la subárbol, mientras que *`y`* desciende a la posición de hijo derecho de *`z`*. Se actualizan las referencias de los padres y las alturas de los nodos para mantener las propiedades del árbol AVL.
#
#
# **Parametros del metodo:**
# ```python
#   def _rotar_derecha(self, y):
# ```
#
# - *`self:`* Es el objeto de la clase *`ArbolAVL`*, lo que permite acceder a otros métodos y atributos de la clase.
# - *`y`*: Es el nodo en el que se quiere realizar la rotación a la derecha, que en este contexto está desbalanceado hacia la izquierda.
#
#
#
# **Funcionamiento del metodo**
#
# **1. Guardar la referencia al padre del nodo `y`:**
# ```python
#   sub_raiz = y.padre
# ```
#
# `sub_raiz` almacena el nodo padre de *`y`. Después de la rotación, *`z`* (el hijo izquierdo de *`y`*) se convertirá en la nueva raíz de la subárbol, y este nodo (*`sub_raiz`*) se utilizará para reestablecer la conexión con el resto del árbol.
#
#
# **2. Asignar el hijo izquierdo de `y` a `z`:**
# ```python
#   z = y.izquierda
# ```
# *`z`* es el hijo izquierdo de *`y`*. Durante la rotación, *`z`* ocupará la posición de *`y`*, convirtiéndose en el nuevo nodo raíz de la subárbol.
#
#
# **3. Almacenar el subárbol derecho de z (antes de la rotación):**
#
# ```python
#   t3 = z.derecha
# ```
#
# *`t3`* representa el subárbol derecho de *`z`*, que podría existir o no. Este subárbol derecho será asignado al hijo izquierdo de y después de la rotación, ya que *`y`* se moverá hacia abajo y tomará el lugar de *`z`*.
#
#
# **4. Realizar la rotación:**
#
# 1. Asignar `y` como hijo derecho de `z`:
#
#   ```python
#     z.derecha = y
#     y.padre = z
#   ```
#
# - El nodo y pasa a ser el hijo derecho de *`z`*. Además, el padre de *`y`* se actualiza para que ahora sea *`z`*.
#
# 2. Asignar `t3` como hijo izquierdo de `y`:
#
#   ```python
#     y.izquierda = t3
#   ```
#
# - El subárbol derecho original de *`z`* (*`t3`*) se asigna como hijo izquierdo de *`y`*.
#
# 3. Actualizar el padre de `t3`:
#
#   ```python
#     if t3 is not None:
#       t3.padre = y
#   ```
#
# - Si *`t3`* no es *`None`* (es decir, si existe un subárbol), su padre se actualiza a *`y`*.
#
# **5. Reestablecer la conexión con el padre original (`sub_raiz`):**
# ```python
#   z.padre = sub_raiz
# ```
#
# Después de la rotación, *`z`* se convierte en la nueva raíz de la subárbol, por lo que su padre debe actualizarse a *`sub_raiz`*, que originalmente era el padre de *`y`*.
#
#
# **6. Actualizar la raíz del árbol si es necesario:**
# ```python
#   if z.padre is None:
#     self.raiz = z
# ```
#
# Si el padre de *`z`* es *`None`*, significa que *`z`* se ha convertido en la nueva raíz del árbol completo. Por lo tanto, se actualiza la raíz del árbol AVL a *`z`*.
#
#
# **7. Reasignar el nodo rotado (z) al padre:**
# ```python
#   else:
#     if z.padre.izquierda == y:
#         z.padre.izquierda = z
#     else:
#         z.padre.derecha = z
# ```
#
# Si *`z`* no es la raíz del árbol, se debe reestablecer la conexión entre *`z`* y su nuevo padre. Dependiendo de si y era el hijo izquierdo o derecho de *`sub_raiz`*, *`z`* reemplazará a *`y`* en la posición correspondiente (izquierda o derecha).
#
#
# **8. Actualizar las alturas de los nodos:**
# ```python
#   y.altura = 1 + max(self._obtener_altura(y.izquierda),
#                       self._obtener_altura(y.derecha))
#
#   z.altura = 1 + max(self._obtener_altura(z.izquierda),
#                       self._obtener_altura(z.derecha))
# ```
#
# Después de la rotación, se recalculan las alturas de *`y`* y *`z`*, ya que su posición en el árbol ha cambiado. La altura se establece como 1 más el máximo de las alturas de sus hijos izquierdo y derecho.

# %% [markdown]
# #### Metodo `_rotar_izquierda`

# %% [markdown]
# ```python
# def _rotar_izquierda(self, z):
#         sub_raiz = z.padre
#         y = z.derecha
#         t2 = y.izquierda
#         y.izquierda = z
#         z.padre = y
#         z.derecha = t2
#
#         if t2 is not None:
#             t2.padre = z
#
#         y.padre = sub_raiz
#
#         if y.padre is None:
#             self.raiz = y
#         else:
#             if y.padre.izquierda == z:
#                 y.padre.izquierda = y
#             else:
#                 y.padre.derecha = y
#
#         z.altura = 1 + max(self._obtener_altura(z.izquierda), self._obtener_altura(z.derecha))
#         y.altura = 1 + max(self._obtener_altura(y.izquierda), self._obtener_altura(y.derecha))
#
#
# ```
#
# El método `_rotar_izquierda` realiza una **rotación simple hacia la izquierda (RR)** en un árbol AVL. Esta rotación es necesaria cuando un nodo está desbalanceado hacia la derecha, lo que significa que su subárbol derecho es más alto que su subárbol izquierdo. La rotación izquierda redistribuye los nodos de tal manera que el árbol vuelva a estar equilibrado.
#
# El hijo derecho del nodo (*`y`*) toma su lugar, y el nodo original (*`z`*) se convierte en el hijo izquierdo de *`y`*. Las referencias de los padres y las alturas de los nodos se actualizan para preservar el balance del árbol AVL.
#
#
# **Parametros del metodo:**
# ```python
#   def _rotar_izquierda(self, z):
# ```
#
# - *`self:`* Es el objeto de la clase *`ArbolAVL`*, lo que permite acceder a otros métodos y atributos de la clase.
# - *`z`*: Es el nodo en el que se aplicará la rotación a la izquierda. En este caso, es un nodo desbalanceado hacia la derecha.
#
#
#
# **Funcionamiento del metodo**
#
# **1. Guardar la referencia al padre de `z`:**
# ```python
#   sub_raiz = z.padre
# ```
#
# Se guarda el nodo padre de *`z`* en la variable *`sub_raiz`*. Esto es importante porque *`z`* va a moverse hacia abajo y su posición será tomada por su hijo derecho *`y`*, por lo que será necesario conectar a *`y`* con el nodo padre de *`z`*.
#
#
# **2. Asignar el hijo izquierdo de `z` a `y`:**
# ```python
#   y = z.derecha
# ```
# *`y`* es el hijo derecho de *`z`* y durante la rotación será elevado para ocupar la posición de *`z`*.
#
#
# **3. Guardar el subárbol izquierdo de y (antes de la rotación):**
#
# ```python
#   t2 = y.izquierda
# ```
#
# Se guarda en *`t2`* el subárbol izquierdo de *`y`*. Este subárbol será reasignado como hijo derecho de *`z`* después de que *`y`* se convierta en la nueva raíz de la subárbol.
#
#
# **4. Realizar la rotación:**
#
# 1. Asignar `z` como hijo derecho de `y`:
#
#   ```python
#     y.izquierda = z
#     z.padre = y
#   ```
#
# - *`y`* toma el lugar de *`z`* como la nueva raíz de la subárbol, y *`z`* se convierte en su hijo izquierdo. Además, se actualiza la referencia del padre de *`z`* para que ahora sea *`y`*.
#
# 2. Asignar `t2` como hijo izquierdo de `z`:
#
#   ```python
#     z.derecha = t2
#   ```
#
# - El subárbol izquierdo original de *`y`* (almacenado en *`t2`*) se convierte en el hijo derecho de *`z`*.
#
# 3. Actualizar el padre de `t2`:
#
#   ```python
#     if t2 is not None:
#       t2.padre = z
#   ```
#
# - Si *`t2`* no es *`None`* (es decir, si existe un subárbol), se actualiza el padre de *`t2`* para que sea *`z`*.
#
# **5. Reestablecer la conexión con el padre original (`sub_raiz`):**
# ```python
#   y.padre = sub_raiz
# ```
#
# Ahora que *`y`* es la nueva raíz de la subárbol, se conecta al padre original de *`z`* (almacenado en *`sub_raiz`*).
#
#
# **6. Actualizar la raíz del árbol si es necesario:**
# ```python
#   if y.padre is None:
#     self.raiz = y
# ```
#
# Si *`y`* no tiene un padre (es decir, si *`y`* se convierte en la nueva raíz del árbol completo), se actualiza la referencia de la raíz del árbol AVL a *`y`*.
#
#
# **7. Reasignar el nuevo nodo (y) al padre:**
# ```python
#   else:
#     if y.padre.izquierda == z:
#         y.padre.izquierda = y
#     else:
#         y.padre.derecha = y
# ```
#
# Si *`y`* no es la nueva raíz del árbol completo, se debe restablecer la conexión con el padre original. Dependiendo de si *`z`* era el hijo izquierdo o derecho de *`sub_raiz`*, se asigna *`y`* en la posición correcta (izquierda o derecha).
#
#
# **8. Actualizar las alturas de los nodos:**
# ```python
#   z.altura = 1 + max(self._obtener_altura(z.izquierda),
#                       self._obtener_altura(z.derecha))
#
#   y.altura = 1 + max(self._obtener_altura(y.izquierda),
#                       self._obtener_altura(y.derecha))
#
# ```
#
# Se recalculan las alturas de *`z`* y *`y`* después de la rotación. La altura se define como 1 más el máximo de las alturas de los hijos izquierdo y derecho del nodo. Esto es necesario para mantener las propiedades del árbol AVL y asegurarse de que los factores de balance sean correctos.

# %% [markdown]
# #### Metodo `eliminar`

# %% [markdown]
# ``` python
# def eliminar(self, valor, nodo_actual):
#     if not self.raiz:
#         print("El árbol está vacío, no se puede eliminar.")
#     return
#
#     if nodo_actual is None:
#         print("El nodo no existe en el árbol.")
#     return nodo_actual
#
#     if valor < nodo_actual.valor:
#         nodo_actual.izquierda = self.eliminar(valor, nodo_actual.izquierda)
#     elif valor > nodo_actual.valor:
#         nodo_actual.derecha = self.eliminar(valor, nodo_actual.derecha)
#     else:
#         if nodo_actual.izquierda is None:
#             temp = nodo_actual.derecha
#             nodo_actual = None
#             return temp
#         elif nodo_actual.derecha is None:
#             temp = nodo_actual.izquierda
#             nodo_actual = None
#             return temp
#
#     temp = self._obtener_minimo(nodo_actual.derecha)
#     nodo_actual.valor = temp.valor
#     nodo_actual.derecha = self.eliminar(temp.valor, nodo_actual.derecha)
#
#     if nodo_actual is None:
#         return nodo_actual
#
#     nodo_actual.altura = 1 + max(self._obtener_altura(nodo_actual.izquierda), self._obtener_altura(nodo_actual.derecha))
#
#     balance = self._obtener_balance(nodo_actual)
#
#     if balance > 1 and self._obtener_balance(nodo_actual.izquierda) >= 0:
#         return self._rotar_derecha(nodo_actual)
#
#     if balance > 1 and self._obtener_balance(nodo_actual.izquierda) < 0:
#         nodo_actual.izquierda = self._rotar_izquierda(nodo_actual.izquierda)
#         return self._rotar_derecha(nodo_actual)
#
#     if balance < -1 and self._obtener_balance(nodo_actual.derecha) <= 0:
#         return self._rotar_izquierda(nodo_actual)
#
#     if balance < -1 and self._obtener_balance(nodo_actual.derecha) > 0:
#         nodo_actual.derecha = self._rotar_derecha(nodo_actual.derecha)
#         return self._rotar_izquierda(nodo_actual)
#
#     return nodo_actual
# ```
#
# El método `eliminar` en la clase `ArbolAVL` permite agregar nuevos nodos al árbol AVL, manteniendo la propiedad de equilibrio del árbol.
#
# **Parametros del metodo:**
# ```python
# def eliminar(self, valor, nodo_actual):
# ```
# Al igual que el metodo insertar, se reciben 3 parametros:
# - *`self:`* Referencia a la instancia actual de la clase ArbolAVL.
# - *`valor:`* El valor del nodo que queremos eliminar.
# - *`nodo_actual:`* El nodo desde el cual comenzamos a buscar el nodo a eliminar.
#
# **Funcionamiento del metodo**
#
# **1. Verificar si el árbol está vacío:**
# ```python
# if not self.raiz:
#     print("El árbol está vacío, no se puede eliminar.")
#     return
# ```
#
# Se comprueba si el árbol está vacío (si *`self.raiz`* es *`None`* ). Si es así, se imprime un mensaje y se termina la ejecución del método.
#
#
# **2. Verificar si el nodo actual es *`None`* :**
# ```python
# if nodo_actual is None:
#     print("El nodo no existe en el árbol.")
#     return nodo_actual
# ```
#
# Si *`nodo_actual`* es *`None`*, significa que hemos llegado a un punto donde el valor no se encuentra en el árbol. Se imprime un mensaje y se retorna *`nodo_actual`*.
#
#
# **3. Buscar el nodo a eliminar:**
# ```python
# if valor < nodo_actual.valor:
#     nodo_actual.izquierda = self.eliminar(valor, nodo_actual.izquierda)
# elif valor > nodo_actual.valor:
#     nodo_actual.derecha = self.eliminar(valor, nodo_actual.derecha)
# else:
# ```
#
# *   Si el *`valor`* que queremos eliminar es **menor** que el *`valor`* del *`nodo_actual`*, se llama recursivamente al subárbol izquierdo para buscar el nodo.
#
# *   Si el *`valor`* que queremos eliminar es **mayor** que el *`valor`* del *`nodo_actual`*, se llama recursivamente al subárbol derecho para buscar el nodo.
#
# *   Si encontramos el valor (*`else`*), llegamos al bloque donde se realiza la eliminación.
#
#
# **4. Eliminar el nodo encontrado:**
# ```python
# if nodo_actual.izquierda is None:
#     temp = nodo_actual.derecha
#     nodo_actual = None
#     return temp
# elif nodo_actual.derecha is None:
#     temp = nodo_actual.izquierda
#     nodo_actual = None
#     return temp
# ```
#
# * **Caso 1:** Si el nodo a eliminar no tiene hijo izquierdo, se guarda el hijo derecho en *`temp`*, se elimina el nodo estableciendo *`nodo_actual`* como *`None`*, y se retorna el hijo derecho.
#
# *  **Caso 2:** Si el nodo no tiene hijo derecho, se guarda el hijo izquierdo en *`temp`*, se elimina el nodo, y se retorna el hijo izquierdo.
#
#
# **5. Caso de eliminación con dos hijos:**
# ```python
# temp = self._obtener_minimo(nodo_actual.derecha)
# nodo_actual.valor = temp.valor
# nodo_actual.derecha = self.eliminar(temp.valor, nodo_actual.derecha)
# ```
#
# Si el nodo tiene dos hijos, se encuentra el sucesor (el valor mínimo del subárbol derecho) y se copia su valor al nodo a *`eliminar`*. Luego, se llama recursivamente al método eliminar para eliminar el sucesor.
#
#
# **6. Chequeo de nodo**
# ```python
# if nodo_actual is None:
#     return nodo_actual
# ```
#
# Después de manejar la eliminación de un nodo con dos hijos (donde se reemplaza el valor del nodo por el valor mínimo del subárbol derecho), y tras ejecutar varias operaciones, puede ocurrir que el nodo actual sea None (es decir, ha sido eliminado completamente o se ha reemplazado por otro nodo). Si es así, el método simplemente retorna None.
#
#
# **7. Actualizar la altura del nodo actual:**
# ```python
# nodo_actual.altura = 1 + max(self._obtener_altura(nodo_actual.izquierda), self._obtener_altura(nodo_actual.derecha))
# ```
#
# Después de la eliminación, se actualiza la altura del nodo actual basándose en las alturas de sus hijos.
#
#
# **8.Verificar el balance y reequilibrar si es necesario:**
# ```python
# balance = self._obtener_balance(nodo_actual)
#
#   if balance > 1 and self._obtener_balance(nodo_actual.izquierda) >= 0:
#     return self._rotar_derecha(nodo_actual)
#
#   if balance > 1 and self._obtener_balance(nodo_actual.izquierda) < 0:
#       nodo_actual.izquierda = self._rotar_izquierda(nodo_actual.izquierda)
#     return self._rotar_derecha(nodo_actual)
#
#   if balance < -1 and self._obtener_balance(nodo_actual.derecha) <= 0:
#     return self._rotar_izquierda(nodo_actual)
#
#   if balance < -1 and self._obtener_balance(nodo_actual.derecha) > 0:
#       nodo_actual.derecha = self._rotar_derecha(nodo_actual.derecha)
#     return self._rotar_izquierda(nodo_actual)
# ```
#
# Se calcula el balance del nodo actual. Si el balance está fuera de los límites (mayor que 1 o menor que -1), se realizan las rotaciones necesarias para reequilibrar el árbol.
#
#
# **9.Retornar el nodo actualizado:**
# ```python
# return nodo_actual
# ```
#
# Finalmente, se retorna el nodo actual, que ahora puede ser None o un nodo balanceado.

# %% [markdown]
# #### Metodo `obtener_minimo`

# %% [markdown]
# ```python
# def obtener_minimo(self, nodo_actual):
#         if nodo_actual is None or nodo_actual.izquierda is None:
#             return nodo_actual
#         return self.obtener_minimo(nodo_actual.izquierda)
# ```
#
# Este método se utiliza para encontrar el nodo con el valor mínimo dentro de un subárbol. En un árbol binario de búsqueda (como un AVL), el valor mínimo siempre se encuentra siguiendo los nodos hijos izquierdos hasta llegar al nodo más a la izquierda.
#
# **Parametros del metodo:**
# ```python
# def obtener_minimo(self, nodo_actual):
# ```
# - *`self:`* Referencia a la instancia actual de la clase ArbolAVL.
# - *`nodo_actual:`* Este es el nodo desde el cual se comenzará la búsqueda del valor mínimo. Puede ser cualquier nodo del árbol, pero usualmente se empieza desde un nodo raíz o un nodo derecho cuando se está eliminando.
#
#
# **Funcionamiento del metodo**
#
# **1. Condicion de parada:**
# ```python
# if nodo_actual is None or nodo_actual.izquierda is None:
#     return nodo_actual
# ```
#
# Aquí hay dos condiciones:
#
# - *`nodo_actual`* is *`None`*: Si el nodo actual es *`None`*, significa que hemos llegado al final de un recorrido o el subárbol está vacío. En este caso, se retorna None porque no hay nada más que buscar.
#
# - *`nodo_actual.izquierda`* is *`None`*: Si el hijo izquierdo del nodo actual es *`None`*, significa que hemos llegado al nodo más a la izquierda, que es el que contiene el valor mínimo en el subárbol. Se retorna este nodo.
#
#
# **2. Recursion para seguir buscando:**
# ```python
# return self.obtener_minimo(nodo_actual.izquierda)
# ```
#
# Si el nodo actual tiene un hijo izquierdo, llamamos al método recursivamente para seguir buscando más a la izquierda. Este proceso se repite hasta que encontramos el nodo más a la izquierda.

# %% [markdown]
# #### Metodo `obtener_maximo`

# %% [markdown]
# ```python
# def obtener_maximo(self, nodo_actual):
#         if nodo_actual is None or nodo_actual.derecha is None:
#             return nodo_actual
#         return self.obtener_maximo(nodo_actual.derecha)
# ```
#
# Este método se utiliza para encontrar el nodo con el valor máximo dentro de un subárbol. En un árbol binario de búsqueda (como un AVL), el valor máximo siempre se encuentra siguiendo los nodos hijos derechos hasta llegar al nodo más a la derecha.
#
# **Parametros del metodo:**
# ```python
# def obtener_maximo(self, nodo_actual):
# ```
# Al igual que el metodo *`obtener_minimo`*, este metodo recibe 2 parametros:
#
# - *`self:`* Referencia a la instancia actual de la clase ArbolAVL.
# - *`nodo_actual:`* Es el nodo desde el cual se comienza la búsqueda del valor máximo. Normalmente, se inicia desde la raíz o desde un nodo izquierdo cuando se busca el mayor valor.
#
#
# **Funcionamiento del metodo**
#
# **1. Condicion de parada:**
# ```python
# if nodo_actual is None or nodo_actual.derecha is None:
#     return nodo_actual
# ```
#
# Aquí hay dos condiciones:
#
# - *`nodo_actual`* is *`None`*: Si el nodo actual es *`None`*, significa que hemos llegado al final de un recorrido o el subárbol está vacío. En este caso, el método retorna *`None`* porque no hay más nodos que buscar.
#
# - *`nodo_actual.derecha`* is *`None`*: Si el hijo derecho del nodo actual es *`None`*, significa que hemos llegado al nodo más a la derecha, que es el que contiene el valor máximo. Este nodo se devuelve como resultado.
#
#
# **2. Recursion para seguir buscando:**
#
# ```python
# return self.obtener_maximo(nodo_actual.derecha)
# ```
#
#
# Si el nodo actual tiene un hijo derecho, el método llama recursivamente a sí mismo, continuando el recorrido hacia la derecha hasta encontrar el nodo más a la derecha.

# %% [markdown]
# #### Metodo `obtener_raiz`

# %% [markdown]
# ```python
# def obtener_raiz(self):
#     if self.raiz is None:
#         print("El árbol está vacío.")
#         return None
#     return self.raiz.valor
#
#
# ```
#
# El método `obtener_raiz` es un método simple que devuelve el valor de la raíz del árbol AVL.
#
# **Parametros del metodo:**
# ```python
# def obtener_raiz(self):
# ```
# - *`self:`* Referencia a la instancia actual de la clase ArbolAVL.
#
#
# **Funcionamiento del metodo**
#
# **1. Verificación del estado del árbol:**
# ```python
#   if self.raiz is None:
# ```
#
# - El método comienza verificando si el árbol está vacío.
#
# - Aquí, *`self.raiz`* es la referencia al nodo raíz del árbol AVL. Si el árbol está vacío (es decir, no tiene ningún nodo), entonces *`self.raiz`* es *`None`*.
#
#
# **2. Acción en caso de que el árbol esté vacío:**
# ```python
#   print("El árbol está vacío.")
#     return None
# ```
#
# - Si la raíz es *`None`*, lo que significa que el árbol no tiene nodos, primero imprime el mensaje:`"El árbol está vacío."` para informar al usuario de esta situación.
#
# - Luego, el método retorna *`None`*, indicando que no hay valor que devolver porque no existe ninguna raíz en el árbol.

# %% [markdown]
# #### Metodo `recorrido_in_order`

# %% [markdown]
# ```python
# def recorrido_in_order(self, nodo):
#     if nodo:
#         self.recorrido_in_order(nodo.izquierda)
#         print(nodo.valor, end=" - ")
#         self.recorrido_in_order(nodo.derecha)
#
#
# ```
#
# Este método realiza un recorrido en orden del árbol binario. Un recorrido en orden significa que primero se visita el subárbol izquierdo, luego el nodo actual y, finalmente, el subárbol derecho.
#
# **izquierda -> nodo actual -> derecha**
#
# Este tipo de recorrido es útil para obtener los valores de los nodos en orden ascendente.
#
# **Parametros del metodo:**
# ```python
#   def recorrido_in_order(self, nodo):
# ```
# - *`self:`* Referencia a la instancia actual de la clase ArbolAVL.
#
# - *`nodo:`* Es el nodo a partir del cual comenzará el recorrido. En la primera llamada, generalmente se pasa la raíz del árbol, pero en llamadas recursivas se pasa a los nodos hijos.
#
#
# **Funcionamiento del metodo**
#
# **1. Verificación inicial del nodo:**
# ```python
#   if nodo:
# ```
#
# Esta línea verifica si el nodo actual no es *`None`*. Es importante porque, al llegar a un nodo que no tiene hijos (es decir, sus hijos son *`None`*), se detiene la recursión. Si el nodo es *`None`*, el método simplemente no hace nada (equivalente a llegar a una hoja del árbol).
#
#
# **2. Recursión hacia el subárbol izquierdo:**
# ```python
#   self.recorrido_in_order(nodo.izquierda)
# ```
#
# Si el nodo tiene un hijo izquierdo, el método llama a sí mismo recursivamente con el hijo izquierdo como nuevo nodo. De esta manera, se exploran todos los nodos del subárbol izquierdo antes de procesar el nodo actual.
#
#
# **3. Impresión del valor del nodo actual:**
# ```python
#   print(nodo.valor, end=" - ")
# ```
#
# Una vez que ha terminado de procesar el subárbol izquierdo, el método imprime el valor del nodo actual. El parámetro `end=" - "` asegura que los valores de los nodos se impriman en una línea, separados por un guion.
#
#
# **4. Recursión hacia el subárbol derecho:**
# ```python
#   self.recorrido_in_order(nodo.derecha)
# ```
#
# Después de imprimir el valor del nodo actual, el método llama a sí mismo recursivamente para procesar el subárbol derecho, si es que existe. Así, el recorrido continúa hacia la derecha después de haber procesado el nodo actual.

# %% [markdown]
# #### Metodo `recorrido_pre_orden`

# %% [markdown]
# ```python
# def recorrido_pre_order(self, nodo):
#     if nodo:
#         print(nodo.valor, end=" - ")
#         self.recorrido_pre_order(nodo.izquierda)
#         self.recorrido_pre_order(nodo.derecha)
#
#
# ```
#
# Este método realiza un recorrido pre-order (preorden) del árbol binario, que implica visitar primero el nodo actual, luego el subárbol izquierdo y finalmente el subárbol derecho. Este tipo de recorrido es útil para crear una copia del árbol o para serializarlo.
#
# **nodo actual -> izquierda -> derecha**
#
# Este tipo de recorrido es útil para obtener los valores de los nodos en orden ascendente.
#
# **Parametros del metodo:**
# ```python
#   def recorrido_in_order(self, nodo):
# ```
# - *`self:`* Referencia a la instancia actual de la clase ArbolAVL.
#
# - *`nodo:`* Es el nodo a partir del cual comenzará el recorrido. En la primera llamada, generalmente se pasa la raíz del árbol, pero en llamadas recursivas se pasa a los nodos hijos.
#
#
# **Funcionamiento del metodo**
#
# **1. Verificación inicial del nodo:**
# ```python
#   if nodo:
# ```
#
# Esta línea verifica si el nodo actual no es *`None`*. Es importante porque, al llegar a un nodo que no tiene hijos (es decir, sus hijos son *`None`*), se detiene la recursión. Si el nodo es *`None`*, el método simplemente no hace nada (equivalente a llegar a una hoja del árbol).
#
#
# **2. Visita al Nodo Actual:**
# ```python
#   print(nodo.valor, end=" - ")
# ```
#
# Si el nodo actual no es *`None`*, se imprime el valor del nodo. El argumento `end=" - "` se utiliza para que los valores se impriman en la misma línea, separados por " - ". Esto proporciona una visualización clara de los valores a medida que se recorren.
#
#
# **3. Recursión hacia el subárbol izquierdo:**
# ```python
#   self.recorrido_pre_order(nodo.izquierda)
# ```
#
# Después de imprimir el valor del nodo actual, se llama recursivamente al método `recorrido_pre_order` para procesar el subárbol izquierdo del nodo actual. Esto garantiza que todos los nodos en el subárbol izquierdo se procesen después de manejar el nodo actual.
#
#
# **4. Recursión hacia el subárbol derecho:**
# ```python
#   self.recorrido_pre_order(nodo.derecha)
# ```
#
# Finalmente, se llama recursivamente al método `recorrido_pre_order` para procesar el subárbol derecho del nodo actual. Esto asegura que todos los nodos en el subárbol derecho se procesen después de haber manejado el nodo actual y el subárbol izquierdo.

# %% [markdown]
# #### Metodo `recorrido_post_orden`

# %% [markdown]
# ```python
# def recorrido_post_order(self, nodo):
#     if nodo:
#         self.recorrido_post_order(nodo.izquierda)
#         self.recorrido_post_order(nodo.derecha)
#         print(nodo.valor, end=" - ")
#
#
# ```
#
# Este método realiza un recorrido post-order (postorden) del árbol binario, lo que significa que visita los nodos hijo izquierdo y derecho antes de procesar el nodo actual.
#
# Este tipo de recorrido es útil para eliminar nodos en un árbol, ya que garantiza que los nodos hijo sean procesados antes de su nodo padre.
#
# **izquierda -> derecha -> nodo actual**
#
# Este tipo de recorrido es útil para obtener los valores de los nodos en orden ascendente.
#
# **Parametros del metodo:**
# ```python
#   def recorrido_post_order(self, nodo):
# ```
# - *`self:`* Referencia a la instancia actual de la clase ArbolAVL.
#
# - *`nodo:`* Es el nodo a partir del cual comenzará el recorrido. En la primera llamada, generalmente se pasa la raíz del árbol, pero en llamadas recursivas se pasa a los nodos hijos.
#
#
# **Funcionamiento del metodo**
#
# **1. Verificación inicial del nodo:**
# ```python
#   if nodo:
# ```
#
# Esta línea verifica si el nodo actual no es *`None`*. Es importante porque, al llegar a un nodo que no tiene hijos (es decir, sus hijos son *`None`*), se detiene la recursión. Si el nodo es *`None`*, el método simplemente no hace nada (equivalente a llegar a una hoja del árbol).
#
#
# **2. Recursión hacia el subárbol izquierdo:**
# ```python
#   self.recorrido_post_order(nodo.izquierda)
#
# ```
#
# Si el nodo es válido, se llama recursivamente al método `recorrido_post_order` con el nodo hijo izquierdo del nodo actual. Esto permite que se procesen todos los nodos en el subárbol izquierdo antes de continuar con el nodo actual.
#
#
# **3. Recursión hacia el subárbol derecho:**
# ```python
#   self.recorrido_post_order(nodo.derecha)
#
# ```
#
# Después de procesar el subárbol izquierdo, se llama recursivamente al método `recorrido_post_order` con el nodo hijo derecho del nodo actual. Esto asegura que todos los nodos en el subárbol derecho se procesen antes de continuar.
#
#
# **4.  Impresión del valor del nodo actual:**
# ```python
#   print(nodo.valor, end=" - ")
#
# ```
#
# Finalmente, se imprime el valor del nodo actual. Esto se hace después de haber recorrido ambos subárboles, lo que es característico del recorrido post-order.

# %% [markdown]
# #### Metodo `buscar`

# %% [markdown]
# ```python
# def buscar(self, nodo, valor):
#         if not nodo or nodo.valor == valor:
#             return nodo
#         if valor < nodo.valor:
#             return self.buscar(nodo.izquierda, valor)
#         return self.buscar(nodo.derecha, valor)
#
#
# ```
#
# El método buscar implementa una búsqueda en un árbol binario de búsqueda, permitiendo encontrar un nodo que contenga un valor específico de manera eficiente. La búsqueda se basa en la propiedad del árbol binario de búsqueda, donde los nodos a la izquierda son menores que el nodo actual y los nodos a la derecha son mayores. Si el valor se encuentra, se retorna el nodo correspondiente; de lo contrario, se retorna None al final de la búsqueda.
#
# **Parametros del metodo:**
# ```python
#   def buscar(self, nodo, valor):
# ```
# - *`self:`* Referencia a la instancia actual de la clase ArbolAVL.
#
# - *`nodo:`* Es el nodo a partir del cual comenzará el recorrido. En la primera llamada, generalmente se pasa la raíz del árbol, pero en llamadas recursivas se pasa a los nodos hijos.
#
# - *`valor:`* El valor que se desea buscar en el árbol.
#
#
# **Funcionamiento del metodo**
#
# **1. Verificación del Nodo Actual:**
# ```python
#   if not nodo or nodo.valor == valor:
#     return nodo
# ```
#
# La primera condición comprueba si el nodo es None o si el valor del nodo actual es igual al valor que se busca. Si alguna de estas condiciones es verdadera, el método retorna el nodo actual. Esto significa que si se encuentra el nodo que contiene el valor buscado, se retorna ese nodo; si el nodo es None, significa que el valor no está presente en el árbol.
#
#
# **2. Comparación del Valor:**
# ```python
#   if valor < nodo.valor:
#       return self.buscar(nodo.izquierda, valor)
#
# ```
#
# Si el *`valor`* buscado es **menor** que el valor del *`nodo actual`*, se realiza una llamada recursiva al método `buscar`, pero esta vez se busca en el subárbol izquierdo del nodo actual. En un árbol binario de búsqueda, todos los valores menores que el nodo actual se encuentran en su subárbol izquierdo.
#
#
# **3. Buscar en el Subárbol Derecho:**
# ```python
#   return self.buscar(nodo.derecha, valor)
#
#
# ```
#
# Si el *`valor`* buscado **no es menor** que el valor del *`nodo actual`*, se asume que debe estar en el subárbol derecho. Por lo tanto, se llama recursivamente al método buscar con el nodo hijo derecho.

# %% [markdown]
# #### Metodo `imprimir_arbol`

# %% [markdown]
# ```python
# def imprimir_arbol(self, nodo, nivel=0):
#         if nodo is not None:
#             self.imprimir_arbol(nodo.derecha, nivel + 1)
#             print(" " * 4 * nivel + "-> " + str(nodo.valor))
#             self.imprimir_arbol(nodo.izquierda, nivel + 1)
#
#
# ```
#
# El método imprimir_arbol proporciona una representación visual del árbol binario, donde los nodos se alinean según su nivel en la jerarquía del árbol. Utiliza un enfoque recursivo para navegar por el árbol y formatear la salida. Primero imprime los nodos del subárbol derecho, luego el nodo actual y, finalmente, los nodos del subárbol izquierdo. Esto permite visualizar la estructura del árbol de una manera que refleja su jerarquía, facilitando la comprensión de cómo están organizados los nodos.
#
# **Parametros del metodo:**
# ```python
#   def imprimir_arbol(self, nodo, nivel=0):
# ```
# - *`self:`* Referencia a la instancia actual de la clase ArbolAVL.
#
# - *`nodo:`* Representa el nodo actual que se va a imprimir. Puede ser la raíz del árbol o cualquier otro nodo en el subárbol.
#
# - *`nivel:`* Es un entero que indica el nivel actual del nodo en el árbol. Se inicializa en 0 para la raíz del árbol y se incrementa a medida que se desciende por el árbol.
#
#
# **Funcionamiento del metodo**
#
# **1. Verificación del Nodo Actual:**
# ```python
#   if nodo is not None:
# ```
#
# Se verifica si el nodo actual no es *`None`*. Si el nodo es *`None`*, significa que no hay nada que imprimir, y el método termina aquí.
#
#
# **2. Impresión del Subárbol Derecho:**
# ```python
#   self.imprimir_arbol(nodo.derecha, nivel + 1)
#
# ```
#
# Se realiza una llamada recursiva para imprimir el subárbol derecho del nodo actual. El parámetro *`nivel`* se incrementa en $1$ para reflejar que estamos un nivel más abajo en la jerarquía del árbol.
#
#
# **3. Impresión del Nodo Actual:**
# ```python
#   print(" " * 4 * nivel + "-> " + str(nodo.valor))
#
#
# ```
#
# Aquí se imprime el valor del nodo actual. La impresión incluye espacios para alinear visualmente el nodo con respecto a su nivel en el árbol. Se utilizan cuatro espacios por cada nivel (multiplicando el valor de *`nivel`* por 4), seguido de la representación del valor del nodo precedido por una flecha (->).
#
#
# **3. Impresión del Subárbol Izquierdo:**
# ```python
#   self.imprimir_arbol(nodo.izquierda, nivel + 1)
#
# ```
#
# Finalmente, se realiza una llamada recursiva para imprimir el subárbol izquierdo del nodo actual, también incrementando el nivel en $1$.

# %% [markdown]
# ### Codigo Completo

# %%
import sys

# Clase Nodo que representa cada nodo en el árbol
class Nodo:
    def __init__(self, valor, padre=None):
        self.valor = valor
        self.padre = padre
        self.izquierda = None
        self.derecha = None
        self.altura = 1

# Clase que representa un Árbol AVL
class ArbolAVL:
    def __init__(self):
        self.raiz = None

    # Método para insertar un nodo en el árbol
    def insertar(self, valor, nodo_actual):
        if not self.raiz:
            self.raiz = Nodo(valor)
            return

        if valor < nodo_actual.valor:
            if nodo_actual.izquierda:
                self.insertar(valor, nodo_actual.izquierda)
            else:
                nodo_actual.izquierda = Nodo(valor, nodo_actual)
                self._revisar_insertar(nodo_actual.izquierda)
        elif valor > nodo_actual.valor:
            if nodo_actual.derecha:
                self.insertar(valor, nodo_actual.derecha)
            else:
                nodo_actual.derecha = Nodo(valor, nodo_actual)
                self._revisar_insertar(nodo_actual.derecha)
        else:
            print("El Valor que estas insertando ya se encuentra en el arbol")


    # Método para verificar e inspeccionar si se necesita reequilibrar tras una inserción
    def _revisar_insertar(self, nodo_actual, camino=[]):
        if nodo_actual.padre is None: return
        camino = [nodo_actual] + camino

        balance = self._obtener_balance(nodo_actual.padre)

        if abs(balance) > 1:
            camino = [nodo_actual.padre] + camino
            self._reequilibrar_nodo(camino[0], camino[1], camino[2])
            return

        nueva_altura = 1 + nodo_actual.altura
        if nueva_altura > nodo_actual.padre.altura:
            nodo_actual.padre.altura = nueva_altura

        self._revisar_insertar(nodo_actual.padre, camino)


    # Método para obtener el balance de un nodo
    def _obtener_balance(self, nodo_actual):
        if nodo_actual is None:
            return 0
        return self._obtener_altura(nodo_actual.izquierda) - self._obtener_altura(nodo_actual.derecha)

    # Método para obtener la altura de un nodo
    def _obtener_altura(self, nodo_actual):
        if nodo_actual is None: return 0
        return nodo_actual.altura


    # Método para reequilibrar el árbol en caso de que se desequilibre
    def _reequilibrar_nodo(self, z, y, x):
        if y == z.izquierda and x == y.izquierda:
            self._rotar_derecha(z)
        elif y == z.izquierda and x == y.derecha:
            self._rotar_izquierda(y)
            self._rotar_derecha(z)
        elif y == z.derecha and x == y.derecha:
            self._rotar_izquierda(z)
        elif y == z.derecha and x == y.izquierda:
            self._rotar_derecha(y)
            self._rotar_izquierda(z)
        else:
            raise Exception('_reequilibrar_nodo: ¡Configuración de nodos z, y, x no reconocida!')


    # Rotación a la derecha
    def _rotar_derecha(self, y):
        sub_raiz = y.padre
        z = y.izquierda
        t3 = z.derecha
        z.derecha = y
        y.padre = z
        y.izquierda = t3

        if t3 is not None:
            t3.padre = y

        z.padre = sub_raiz

        if z.padre is None:
            self.raiz = z
        else:
            if z.padre.izquierda == y:
                z.padre.izquierda = z
            else:
                z.padre.derecha = z

        y.altura = 1 + max(self._obtener_altura(y.izquierda), self._obtener_altura(y.derecha))
        z.altura = 1 + max(self._obtener_altura(z.izquierda), self._obtener_altura(z.derecha))


    # Rotación a la izquierda
    def _rotar_izquierda(self, z):
        sub_raiz = z.padre
        y = z.derecha
        t2 = y.izquierda
        y.izquierda = z
        z.padre = y
        z.derecha = t2

        if t2 is not None:
            t2.padre = z

        y.padre = sub_raiz

        if y.padre is None:
            self.raiz = y
        else:
            if y.padre.izquierda == z:
                y.padre.izquierda = y
            else:
                y.padre.derecha = y

        z.altura = 1 + max(self._obtener_altura(z.izquierda), self._obtener_altura(z.derecha))
        y.altura = 1 + max(self._obtener_altura(y.izquierda), self._obtener_altura(y.derecha))


    # Método para eliminar un nodo del árbol
    def eliminar(self, valor, nodo_actual):
        if not self.raiz:
            print("El árbol está vacío, no se puede eliminar.")
            return

        if nodo_actual is None:
            print("El nodo no existe en el árbol.")
            return nodo_actual

        if valor < nodo_actual.valor:
            nodo_actual.izquierda = self.eliminar(valor, nodo_actual.izquierda)
        elif valor > nodo_actual.valor:
            nodo_actual.derecha = self.eliminar(valor, nodo_actual.derecha)
        else:
            if nodo_actual.izquierda is None:
                temp = nodo_actual.derecha
                nodo_actual = None
                return temp
            elif nodo_actual.derecha is None:
                temp = nodo_actual.izquierda
                nodo_actual = None
                return temp

            temp = self.obtener_minimo(nodo_actual.derecha)
            nodo_actual.valor = temp.valor
            nodo_actual.derecha = self.eliminar(temp.valor, nodo_actual.derecha)

        if nodo_actual is None:
            return nodo_actual

        nodo_actual.altura = 1 + max(self._obtener_altura(nodo_actual.izquierda), self._obtener_altura(nodo_actual.derecha))

        balance = self._obtener_balance(nodo_actual)

        if balance > 1 and self._obtener_balance(nodo_actual.izquierda) >= 0:
            return self._rotar_derecha(nodo_actual)

        if balance > 1 and self._obtener_balance(nodo_actual.izquierda) < 0:
            nodo_actual.izquierda = self._rotar_izquierda(nodo_actual.izquierda)
            return self._rotar_derecha(nodo_actual)

        if balance < -1 and self._obtener_balance(nodo_actual.derecha) <= 0:
            return self._rotar_izquierda(nodo_actual)

        if balance < -1 and self._obtener_balance(nodo_actual.derecha) > 0:
            nodo_actual.derecha = self._rotar_derecha(nodo_actual.derecha)
            return self._rotar_izquierda(nodo_actual)

        return nodo_actual

    # Método para obtener el valor mínimo en el árbol
    def obtener_minimo(self, nodo_actual):
        if nodo_actual is None or nodo_actual.izquierda is None:
            return nodo_actual
        return self.obtener_minimo(nodo_actual.izquierda)


    # Método para obtener el valor máximo en el árbol
    def obtener_maximo(self, nodo_actual):
        if nodo_actual is None or nodo_actual.derecha is None:
            return nodo_actual
        return self.obtener_maximo(nodo_actual.derecha)


    # Método para obtener la raíz del árbol
    def obtener_raiz(self):
        return self.raiz.valor

    # Recorrido en orden del árbol
    def recorrido_in_order(self, nodo):
        if nodo:
            self.recorrido_in_order(nodo.izquierda)
            print(nodo.valor, end=" - ")
            self.recorrido_in_order(nodo.derecha)


    # Recorrido en preorden del árbol
    def recorrido_pre_order(self, nodo):
        if nodo:
            print(nodo.valor, end=" - ")
            self.recorrido_pre_order(nodo.izquierda)
            self.recorrido_pre_order(nodo.derecha)


    # Recorrido en postorden del árbol
    def recorrido_post_order(self, nodo):
        if nodo:
            self.recorrido_post_order(nodo.izquierda)
            self.recorrido_post_order(nodo.derecha)
            print(nodo.valor, end=" - ")

    # Metodo para buscar en el arbol
    def buscar(self, nodo, valor):
        if not nodo or nodo.valor == valor:
            return nodo
        if valor < nodo.valor:
            return self.buscar(nodo.izquierda, valor)
        return self.buscar(nodo.derecha, valor)


    # Método para imprimir el árbol
    def imprimir_arbol(self, nodo, nivel=0):
        if nodo is not None:
            self.imprimir_arbol(nodo.derecha, nivel + 1)
            print(" " * 4 * nivel + "-> " + str(nodo.valor))
            self.imprimir_arbol(nodo.izquierda, nivel + 1)


def main():
    arbol = ArbolAVL()

    while True:

        print("\n"
            +"-" * 40
            + "\n\n\t Menú del Árbol AVL\n"
            + "\n1. ¿Esta vacio el Arbol?"
            + "\n2. Insertar un nodo"
            + "\n3. Eliminar un nodo"
            + "\n4. Buscar un nodo"
            + "\n5. Recorrido en preorden"
            + "\n6. Recorrido en inorden"
            + "\n7. Recorrido en postorden"
            + "\n8. Obtener Raiz"
            + "\n9. Obtener Valor Maximo del Arbol"
            + "\n10. Obtener Valor Minimo del Arbol"
            + "\n11. Obtener Factor de Balance de Cierto Nodo"
            + "\n12. Obtener Altura Total del Arbol"
            + "\n13. Imprimir árbol"
            + "\n0. Salir\n\n"
            + "-" * 40)

        opcion = input("\nSelecciona una opción: ")

        if opcion == "1":
            if arbol.raiz is None:
                print("\nEl árbol está vacío.")
            else:
                print("\nEl árbol no está vacío.")

        elif opcion == "2":
            nodo = int(input("\nIngrese el valor del nodo: "))
            arbol.insertar(nodo, arbol.raiz)
            print(f"Nodo {nodo} insertado.")

        elif opcion == "3":
            nodo = int(input("\nIngrese el valor del nodo a eliminar: "))
            arbol.eliminar(nodo, arbol.raiz)
            print(f"Nodo {nodo} eliminado.")

        elif opcion == "4":
            nodo = int(input("\nIngrese el nodo a buscar: "))
            resultado = arbol.buscar(arbol.raiz, nodo)
            print(f"Búsqueda del nodo {nodo}: {'Encontrado' if resultado else 'No encontrado'}")

        elif opcion == "5":
            print("\nRecorrido en preorden: ", end="")
            arbol.recorrido_pre_order(arbol.raiz)
            print()

        elif opcion == "6":
            print("\nRecorrido en inorden: ", end="")
            arbol.recorrido_in_order(arbol.raiz)
            print()

        elif opcion == "7":
            print("\nRecorrido en postorden: ", end="")
            arbol.recorrido_post_order(arbol.raiz)
            print()

        elif opcion == "8":
            if arbol.raiz is None:
                print("\nEl árbol está vacío.")
            else:
                print("\nRaíz del árbol: ", arbol.obtener_raiz())

        elif opcion == "9":
            print(f"\nValor Maximo del Arbol: {arbol.obtener_maximo(arbol.raiz).valor}")

        elif opcion == "10":
            print(f"\nValor Minimo del Arbol: {arbol.obtener_minimo(arbol.raiz).valor}")

        elif opcion == "11":
            nodo = int(input("\nIngrese el nodo para obtener el factor de balance: "))
            print(f"\nEl Factor de balance del nodo {nodo} es {arbol._obtener_balance(arbol.buscar(arbol.raiz, nodo))}")

        elif opcion == "12":
            print(f"\nLa Altura Total del Arbol es {arbol._obtener_altura(arbol.raiz)}")

        elif opcion == "13":
            print("\nÁrbol AVL actual:\n")
            arbol.imprimir_arbol(arbol.raiz)

        elif opcion == "0":
            print("Saliendo del programa.")
            break

        else:
            print("Opción inválida. Inténtalo de nuevo.")

# Función principal para ejecutar el programa
if __name__ == "__main__":
    main()
# Out:
# ----------------------------------------
#
# 	 Menú del Árbol AVL
#
# 1. ¿Esta vacio el Arbol?
# 2. Insertar un nodo
# 3. Eliminar un nodo
# 4. Buscar un nodo
# 5. Recorrido en preorden
# 6. Recorrido en inorden
# 7. Recorrido en postorden
# 8. Obtener Raiz
# 9. Obtener Valor Maximo del Arbol
# 10. Obtener Valor Minimo del Arbol
# 11. Obtener Factor de Balance de Cierto Nodo
# 12. Obtener Altura Total del Arbol
# 13. Imprimir árbol
# 0. Salir
#
# ----------------------------------------
#
# Selecciona una opción: 1
#
# El árbol está vacío.
#
# ----------------------------------------
#
# 	 Menú del Árbol AVL
#
# 1. ¿Esta vacio el Arbol?
# 2. Insertar un nodo
# 3. Eliminar un nodo
# 4. Buscar un nodo
# 5. Recorrido en preorden
# 6. Recorrido en inorden
# 7. Recorrido en postorden
# 8. Obtener Raiz
# 9. Obtener Valor Maximo del Arbol
# 10. Obtener Valor Minimo del Arbol
# 11. Obtener Factor de Balance de Cierto Nodo
# 12. Obtener Altura Total del Arbol
# 13. Imprimir árbol
# 0. Salir
# ...
